# %%
import pandas as pd

# %%
datos = pd.read_csv("train.csv", sep=",")
# Display de dataset
train = pd.DataFrame(datos)
train.head()
# Out:
#        ID  PERIODO_ACADEMICO            E_PRGM_ACADEMICO E_PRGM_DEPARTAMENTO  \
# 0  904256              20212                  ENFERMERIA              BOGOTÁ
# 1  645256              20212                     DERECHO           ATLANTICO
# 2  308367              20203       MERCADEO Y PUBLICIDAD              BOGOTÁ
# 3  470353              20195  ADMINISTRACION DE EMPRESAS           SANTANDER
# 4  989032              20212                  PSICOLOGIA           ANTIOQUIA
#
#                 E_VALORMATRICULAUNIVERSIDAD E_HORASSEMANATRABAJA  \
# 0  Entre 5.5 millones y menos de 7 millones    Menos de 10 horas
# 1  Entre 2.5 millones y menos de 4 millones                    0
# 2  Entre 2.5 millones y menos de 4 millones      Más de 30 horas
# 3  Entre 4 millones y menos de 5.5 millones                    0
# 4  Entre 2.5 millones y menos de 4 millones  Entre 21 y 30 horas
#
#   F_ESTRATOVIVIENDA F_TIENEINTERNET                    F_EDUCACIONPADRE  \
# 0         Estrato 3              Si    Técnica o tecnológica incompleta
# 1         Estrato 3              No      Técnica o tecnológica completa
# 2         Estrato 3              Si  Secundaria (Bachillerato) completa
# 3         Estrato 4              Si                             No sabe
# 4         Estrato 3              Si                   Primaria completa
#
#   F_TIENELAVADORA  ... E_PRIVADO_LIBERTAD E_PAGOMATRICULAPROPIO  \
# 0              Si  ...                  N                    No
# 1              Si  ...                  N                    No
# 2              Si  ...                  N                    No
# 3              Si  ...                  N                    No
# 4              Si  ...                  N                    No
#
#   F_TIENECOMPUTADOR F_TIENEINTERNET.1                    F_EDUCACIONMADRE  \
# 0                Si                Si                           Postgrado
# 1                Si                No    Técnica o tecnológica incompleta
# 2                No                Si  Secundaria (Bachillerato) completa
# 3                Si                Si  Secundaria (Bachillerato) completa
# 4                Si                Si                   Primaria completa
#
#   RENDIMIENTO_GLOBAL INDICADOR_1  INDICADOR_2  INDICADOR_3  INDICADOR_4
# 0         medio-alto       0.322        0.208        0.310        0.267
# 1               bajo       0.311        0.215        0.292        0.264
# 2               bajo       0.297        0.214        0.305        0.264
# 3               alto       0.485        0.172        0.252        0.190
# 4         medio-bajo       0.316        0.232        0.285        0.294
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Manejo de datos faltantes

# %%
missing_values = train.isnull().sum()
print("Valores faltantes por columna:")
print(missing_values[missing_values > 0])
# Out:
# Valores faltantes por columna:
# E_VALORMATRICULAUNIVERSIDAD     6287
# E_HORASSEMANATRABAJA           30857
# F_ESTRATOVIVIENDA              32137
# F_TIENEINTERNET                26629
# F_EDUCACIONPADRE               23178
# F_TIENELAVADORA                39773
# F_TIENEAUTOMOVIL               43623
# E_PAGOMATRICULAPROPIO           6498
# F_TIENECOMPUTADOR              38103
# F_TIENEINTERNET.1              26629
# F_EDUCACIONMADRE               23664
# dtype: int64

# %%
# Impute missing values
for column in train.columns:
    if train[column].isnull().any():
        if train[column].dtype == 'object':
            # Impute categorical columns with mode
            mode_value = train[column].mode()[0]
            train[column] = train[column].fillna(mode_value)
        elif train[column].dtype in ['int64', 'float64']:
            # Impute numerical columns with median
            median_value = train[column].median()
            train[column] = train[column].fillna(median_value)

# Verify no remaining missing values
print("\nMissing values after imputation:")
print(train.isnull().sum())
# Out:
# Missing values after imputation:
# ID                             0
# PERIODO_ACADEMICO              0
# E_PRGM_ACADEMICO               0
# E_PRGM_DEPARTAMENTO            0
# E_VALORMATRICULAUNIVERSIDAD    0
# E_HORASSEMANATRABAJA           0
# F_ESTRATOVIVIENDA              0
# F_TIENEINTERNET                0
# F_EDUCACIONPADRE               0
# F_TIENELAVADORA                0
# F_TIENEAUTOMOVIL               0
# E_PRIVADO_LIBERTAD             0
# E_PAGOMATRICULAPROPIO          0
# F_TIENECOMPUTADOR              0
# F_TIENEINTERNET.1              0
# F_EDUCACIONMADRE               0
# RENDIMIENTO_GLOBAL             0
# INDICADOR_1                    0
# INDICADOR_2                    0
# INDICADOR_3                    0
# INDICADOR_4                    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder


# 1. Separar las características (X) de la variable objetivo (y)
# X contendrá todas las columnas EXCEPTO la que queremos predecir.
X = train.drop('RENDIMIENTO_GLOBAL', axis=1)

# y contendrá SOLAMENTE la columna que queremos predecir.
y_texto = train['RENDIMIENTO_GLOBAL']

# 2. Instanciar el LabelEncoder
le = LabelEncoder()

# 3. Aplicar fit_transform a 'y'
# Esto aprende las categorías y las transforma en números
y = le.fit_transform(y_texto)


print("Mapeo de LabelEncoder:")
# Itera sobre las clases aprendidas y muestra su número
for i, clase in enumerate(le.classes_):
    print(f"{clase}  ->  {i}")

print("\nPrimeras 5 etiquetas en texto:")
print(y_texto.head())

print("\nPrimeras 5 etiquetas codificadas (como números):")
print(y[:5])

print(f"\nDimensiones de X (features): {X.shape}")
print(f"Dimensiones de y (target): {y.shape}")
# Out:
# Mapeo de LabelEncoder:
# alto  ->  0
# bajo  ->  1
# medio-alto  ->  2
# medio-bajo  ->  3
#
# Primeras 5 etiquetas en texto:
# 0    medio-alto
# 1          bajo
# 2          bajo
# 3          alto
# 4    medio-bajo
# Name: RENDIMIENTO_GLOBAL, dtype: object
#
# Primeras 5 etiquetas codificadas (como números):
# [2 1 1 0 3]
#
# Dimensiones de X (features): (692500, 20)
# Dimensiones de y (target): (692500,)

# %% [markdown]
# ## Convertir variables categoricas one-hot

# %%
# Identificar las columnas categóricas excluyendo RENDIMIENTO_GLOBAL
categorical_cols = X.select_dtypes(include=['object']).columns
#aplicar get_dummies a las features
X_transformado = pd.get_dummies(X, columns=categorical_cols)

print(f"Dimensiones de X después de One-Hot Encoding: {X_transformado.shape}")
# Out:
# Dimensiones de X después de One-Hot Encoding: (692500, 1043)

# %%
print(X_transformado.shape)
# Out:
# (692500, 1043)

# %% [markdown]
# ## Normalización

# %%
numerical_cols = X_transformado.select_dtypes(include=['int64', 'float64']).columns.tolist()
numerical_cols.remove('ID')
numerical_cols.remove('PERIODO_ACADEMICO')

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_transformado[numerical_cols] = scaler.fit_transform(X_transformado[numerical_cols])

display(X_transformado.head())
# Out:
#        ID  PERIODO_ACADEMICO  INDICADOR_1  INDICADOR_2  INDICADOR_3  \
# 0  904256              20212     0.437002    -0.556223     0.813978
# 1  645256              20212     0.346934    -0.481341     0.508180
# 2  308367              20203     0.232301    -0.492038     0.729034
# 3  470353              20195     1.771650    -0.941332    -0.171371
# 4  989032              20212     0.387874    -0.299484     0.389259
#
#    INDICADOR_4  \
# 0     0.060296
# 1     0.016142
# 2     0.016142
# 3    -1.072993
# 4     0.457683
#
#    E_PRGM_ACADEMICO_3°  CICLO PROFESIONAL NEGOCIOS INTERNACIONALES  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    E_PRGM_ACADEMICO_ACTIVIDAD FISICA Y DEPORTE  E_PRGM_ACADEMICO_ACUICULTURA  \
# 0                                        False                         False
# 1                                        False                         False
# 2                                        False                         False
# 3                                        False                         False
# 4                                        False                         False
#
#    E_PRGM_ACADEMICO_ADMINISTRACION  ...  F_EDUCACIONMADRE_Ninguno  \
# 0                            False  ...                     False
# 1                            False  ...                     False
# 2                            False  ...                     False
# 3                            False  ...                     False
# 4                            False  ...                     False
#
#    F_EDUCACIONMADRE_No Aplica  F_EDUCACIONMADRE_No sabe  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
#
#    F_EDUCACIONMADRE_Postgrado  F_EDUCACIONMADRE_Primaria completa  \
# 0                        True                               False
# 1                       False                               False
# 2                       False                               False
# 3                       False                               False
# 4                       False                                True
#
#    F_EDUCACIONMADRE_Primaria incompleta  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    F_EDUCACIONMADRE_Secundaria (Bachillerato) completa  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                              False
#
#    F_EDUCACIONMADRE_Secundaria (Bachillerato) incompleta  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    F_EDUCACIONMADRE_Técnica o tecnológica completa  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    F_EDUCACIONMADRE_Técnica o tecnológica incompleta
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 1043 columns]

# %%
display(X_transformado.head())
display(X_transformado.info())
display(X_transformado.describe())
# Out:
#        ID  PERIODO_ACADEMICO  INDICADOR_1  INDICADOR_2  INDICADOR_3  \
# 0  904256              20212     0.437002    -0.556223     0.813978
# 1  645256              20212     0.346934    -0.481341     0.508180
# 2  308367              20203     0.232301    -0.492038     0.729034
# 3  470353              20195     1.771650    -0.941332    -0.171371
# 4  989032              20212     0.387874    -0.299484     0.389259
#
#    INDICADOR_4  \
# 0     0.060296
# 1     0.016142
# 2     0.016142
# 3    -1.072993
# 4     0.457683
#
#    E_PRGM_ACADEMICO_3°  CICLO PROFESIONAL NEGOCIOS INTERNACIONALES  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    E_PRGM_ACADEMICO_ACTIVIDAD FISICA Y DEPORTE  E_PRGM_ACADEMICO_ACUICULTURA  \
# 0                                        False                         False
# 1                                        False                         False
# 2                                        False                         False
# 3                                        False                         False
# 4                                        False                         False
#
#    E_PRGM_ACADEMICO_ADMINISTRACION  ...  F_EDUCACIONMADRE_Ninguno  \
# 0                            False  ...                     False
# 1                            False  ...                     False
# 2                            False  ...                     False
# 3                            False  ...                     False
# 4                            False  ...                     False
#
#    F_EDUCACIONMADRE_No Aplica  F_EDUCACIONMADRE_No sabe  \
# 0                       False                     False
# 1                       False                     False
# 2                       False                     False
# 3                       False                     False
# 4                       False                     False
#
#    F_EDUCACIONMADRE_Postgrado  F_EDUCACIONMADRE_Primaria completa  \
# 0                        True                               False
# 1                       False                               False
# 2                       False                               False
# 3                       False                               False
# 4                       False                                True
#
#    F_EDUCACIONMADRE_Primaria incompleta  \
# 0                                 False
# 1                                 False
# 2                                 False
# 3                                 False
# 4                                 False
#
#    F_EDUCACIONMADRE_Secundaria (Bachillerato) completa  \
# 0                                              False
# 1                                              False
# 2                                               True
# 3                                               True
# 4                                              False
#
#    F_EDUCACIONMADRE_Secundaria (Bachillerato) incompleta  \
# 0                                              False
# 1                                              False
# 2                                              False
# 3                                              False
# 4                                              False
#
#    F_EDUCACIONMADRE_Técnica o tecnológica completa  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
#
#    F_EDUCACIONMADRE_Técnica o tecnológica incompleta
# 0                                              False
# 1                                               True
# 2                                              False
# 3                                              False
# 4                                              False
#
# [5 rows x 1043 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 692500 entries, 0 to 692499
# Columns: 1043 entries, ID to F_EDUCACIONMADRE_Técnica o tecnológica incompleta
# dtypes: bool(1037), float64(4), int64(2)
# memory usage: 716.6 MB
# None
#                   ID  PERIODO_ACADEMICO   INDICADOR_1   INDICADOR_2  \
# count  692500.000000      692500.000000  6.925000e+05  6.925000e+05
# mean   494606.130576       20198.366679 -1.178731e-16 -1.508711e-16
# std    285585.209455          10.535037  1.000001e+00  1.000001e+00
# min         1.000000       20183.000000 -2.199542e+00 -2.781294e+00
# 25%    247324.750000       20195.000000 -5.373728e-01 -5.134332e-01
# 50%    494564.500000       20195.000000 -2.344159e-01  1.177168e-01
# 75%    741782.500000       20203.000000  3.714978e-01  5.242203e-01
# max    989286.000000       20213.000000  3.179990e+00  2.428368e+00
#
#         INDICADOR_3   INDICADOR_4
# count  6.925000e+05  6.925000e+05
# mean   2.909070e-16  6.960754e-17
# std    1.000001e+00  1.000001e+00
# min   -4.452543e+00 -3.869422e+00
# 25%   -1.373936e-01 -1.163206e-01
# 50%    2.363596e-01  3.252207e-01
# 75%    5.251688e-01  5.901454e-01
# max    9.838658e-01  1.016969e+00

# %%
# 1. Guardar X_transformado como Parquet
print("Guardando X_transformado en formato Parquet...")
X_transformado.to_parquet('X_train_procesado.parquet', index=False)
print("¡Listo!")

# 2. Guardar 'y'
import numpy as np
print("Guardando y_train...")
np.save('y_train_procesado.npy', y)
print("¡Listo!")

# %% [markdown]
# # MODELO XGB

# %%
X_train_procesado = pd.read_parquet('X_train_procesado.parquet')
print("X_train_procesado cargado.")
# Out:
# X_train_procesado cargado.

# %%
import numpy as np
y_train_procesado = np.load('y_train_procesado.npy')
print("y_train_procesado cargado.")
# Out:
# y_train_procesado cargado.

# %%
import numpy as np
import pandas as pd


# Asegurar que ambas variables existen antes de proceder
if 'X_train_procesado' in globals() and 'y_train_procesado' in globals():
    len_X = X_train_procesado.shape[0]
    try:
        len_y = y_train_procesado.shape[0]
    except Exception:
        len_y = len(y_train_procesado)

    if len_X != len_y:
        print(f'Inconsistencia detectada: len(X)={len_X}, len(y)={len_y}. Alineando de forma segura...')
        # Preferir eliminar entradas con y NaN si y es Series
        if isinstance(y_train_procesado, (pd.Series, pd.DataFrame)):
            mask = ~y_train_procesado.isnull()
            y_train_procesado = y_train_procesado.loc[mask].reset_index(drop=True)
            # Si X tiene al menos tantas filas como mask.sum(), aplicamos la misma máscara por posición
            if X_train_procesado.shape[0] >= mask.sum():
                X_train_procesado = X_train_procesado.iloc[:mask.sum()].reset_index(drop=True)
            else:
                X_train_procesado = X_train_procesado.iloc[:y_train_procesado.shape[0]].reset_index(drop=True)
        else:
            # y es numpy array: truncar el más largo para alinear por posición
            if len_X > len_y:
                X_train_procesado = X_train_procesado.iloc[:len_y].reset_index(drop=True)
            else:
                y_train_procesado = y_train_procesado[:len_X]
        print('Alineamiento completado. Nuevas longitudes:', X_train_procesado.shape[0], getattr(y_train_procesado, 'shape', len(y_train_procesado)))
    else:
        print('X e y ya estaban alineados. len=', len_X)
else:
    print('Aviso: X_train_procesado o y_train_procesado no están definidas en el kernel. Ejecuta las celdas de preprocesamiento apropiadas antes de entrenar.')
# Out:
# X e y ya estaban alineados. len= 692500

# %%
test_df = pd.read_csv('test.csv', sep=',')
print("test_df cargado.")
# Out:
# test_df cargado.

# %%
missing_values_test = test_df.isnull().sum()
print("Valores faltantes por columna en test_df:")
print(missing_values_test[missing_values_test > 0])
# Out:
# Valores faltantes por columna en test_df:
# E_VALORMATRICULAUNIVERSIDAD     2723
# E_HORASSEMANATRABAJA           13379
# F_ESTRATOVIVIENDA              13795
# F_TIENEINTERNET                11539
# F_EDUCACIONPADRE                9993
# F_TIENELAVADORA                17259
# F_TIENEAUTOMOVIL               18918
# E_PAGOMATRICULAPROPIO           2807
# F_TIENECOMPUTADOR              16439
# F_TIENEINTERNET.1              11539
# F_EDUCACIONMADRE               10223
# dtype: int64

# %%
for column in test_df.columns:
    if test_df[column].isnull().any():
        if test_df[column].dtype == 'object':
            mode_value = test_df[column].mode()[0]
            test_df[column] = test_df[column].fillna(mode_value)
        elif test_df[column].dtype in ['int64', 'float64']:
            median_value = test_df[column].median()
            test_df[column] = test_df[column].fillna(median_value)

print("Missing values in test_df after imputation:")
print(test_df.isnull().sum()[test_df.isnull().sum() > 0])
# Out:
# Missing values in test_df after imputation:
# Series([], dtype: int64)

# %%
categorical_cols_test = test_df.select_dtypes(include=['object']).columns
X_test_transformed = pd.get_dummies(test_df, columns=categorical_cols_test)

print(f"Dimensiones de X_test_transformed después de One-Hot Encoding: {X_test_transformed.shape}")
# Out:
# Dimensiones de X_test_transformed después de One-Hot Encoding: (296786, 1014)

# %%
train_cols = X_train_procesado.columns
test_cols = X_test_transformed.columns

missing_in_test = set(train_cols) - set(test_cols)
for c in missing_in_test:
    X_test_transformed[c] = 0

missing_in_train = set(test_cols) - set(train_cols)
X_test_transformed = X_test_transformed.drop(columns=list(missing_in_train))

X_test_transformed = X_test_transformed[train_cols]

print(f"Dimensiones de X_test_transformed después de la alineación de columnas: {X_test_transformed.shape}")
print(f"Columnas de X_test_transformed son iguales a las de X_train_procesado: {all(X_test_transformed.columns == X_train_procesado.columns)}")
# Out:
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# ...
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# /var/folders/4p/5cp_zzdd5h99gz5mkdx4h56h0000gn/T/ipykernel_36752/875242137.py:6: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X_test_transformed[c] = 0
# Dimensiones de X_test_transformed después de la alineación de columnas: (296786, 1039)
# Columnas de X_test_transformed son iguales a las de X_train_procesado: True

# %%
from sklearn.model_selection import train_test_split

print("Librería train_test_split importada.")
# Out:
# Librería train_test_split importada.

# %%
X_train_sampled_eval, X_val_sampled_eval, y_train_sampled_eval, y_val_sampled_eval = train_test_split(
    X_train_procesado, y_train_procesado, test_size=0.8, stratify=y_train_procesado, random_state=42
)

print(f"Dimensiones de X_train_sampled_eval: {X_train_sampled_eval.shape}")
print(f"Dimensiones de y_train_sampled_eval: {y_train_sampled_eval.shape}")
print(f"Dimensiones de X_val_sampled_eval: {X_val_sampled_eval.shape}")
print(f"Dimensiones de y_val_sampled_eval: {y_val_sampled_eval.shape}")
# Out:
# Dimensiones de X_train_sampled_eval: (138500, 1039)
# Dimensiones de y_train_sampled_eval: (138500,)
# Dimensiones de X_val_sampled_eval: (554000, 1039)
# Dimensiones de y_val_sampled_eval: (554000,)

# %%
import unicodedata
import re
import pandas as pd

def sanitize_and_deduplicate_cols(df):
    """
    Sanitiza nombres de columnas y maneja duplicados secuencialmente.
    """
    def sanitize(col):
        # 1. Normalizar a ASCII 
        new_col = unicodedata.normalize('NFKD', col).encode('ascii', 'ignore').decode('utf-8')
        
        # 2. Reemplazar caracteres especiales y espacios por guiones bajos
        new_col = re.sub(r'[^a-zA-Z0-9_]', '_', new_col)
        
        # 3. Eliminar guiones bajos duplicados o iniciales/finales
        new_col = re.sub(r'_+', '_', new_col).strip('_')
        
         
        new_col = new_col.replace('[', '_').replace(']', '_')
        
        return new_col

    sanitized_cols = [sanitize(col) for col in df.columns]
    
    # --- Manejo de Duplicados ---
    counts = {}
    final_cols = []
    for col in sanitized_cols:
        original_col = col
        if col in counts:
            counts[col] += 1
            # Añadir sufijo secuencial (e.g., _2, _3)
            col = f"{original_col}_{counts[original_col]}"
        else:
            counts[col] = 1
        final_cols.append(col)
        
    df.columns = final_cols
    return df

# --- Aplicar la limpieza a todos los conjuntos de datos de características ---

# 1. Aplicar a los datos de entrenamiento completo
X_train_procesado = sanitize_and_deduplicate_cols(X_train_procesado)



# 2. Aplicar al conjunto de prueba
X_test_transformed = sanitize_and_deduplicate_cols(X_test_transformed)

print("Nombres de columnas sanitizados y duplicados renombrados exitosamente.")
print(f"Número de columnas final en X_train: {X_train_procesado.shape[1]}")
# Out:
# Nombres de columnas sanitizados y duplicados renombrados exitosamente.
# Número de columnas final en X_train: 1039

# %% [markdown]
# ## Entrenar Modelo XGBoost

# %%
import xgboost as xgb
from sklearn.metrics import f1_score
from sklearn.model_selection import RandomizedSearchCV

# Si el LabelEncoder se perdió, lo re-instanciamos para el inverse_transform
try:
    le
except NameError:
    from sklearn.preprocessing import LabelEncoder
    le = LabelEncoder()
    # las clases son las mismas que se usaron en el preprocesamiento inicial
    le.fit(['alto', 'bajo', 'medio-alto', 'medio-bajo']) 

print("Librerías de XGBoost importadas.")
# Out:
# Librerías de XGBoost importadas.

# %%
print("Iniciando RandomizedSearchCV para XGBoost (en datos muestreados)...")


param_dist_xgb = {
    'n_estimators': [100, 200, 300],  
    'max_depth': [3, 5, 7, 9],        
    'learning_rate': [0.01, 0.05, 0.1, 0.2], 
    'subsample': [0.7, 0.8, 0.9],     
    'colsample_bytree': [0.7, 0.8, 0.9], 
}

xgb_model = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=len(le.classes_), 
    eval_metric='mlogloss',
    use_label_encoder=False,
    random_state=42,
    tree_method='hist' 
)

random_search_xgb = RandomizedSearchCV(
    estimator=xgb_model,
    param_distributions=param_dist_xgb,
    n_iter=70, 
    cv=3,       
    scoring='f1_weighted',
    random_state=42,
    n_jobs=-1  
)

random_search_xgb.fit(X_train_sampled_eval, y_train_sampled_eval)

print("--- Búsqueda de Hiperparámetros Completada ---")
print(f"Mejores parámetros: {random_search_xgb.best_params_}")
print(f"Mejor F1-Score (ponderado) en validación muestreada: {random_search_xgb.best_score_:.4f}")

# Guardamos los mejores parámetros
best_params_xgb = random_search_xgb.best_params_
# Out:
# Iniciando RandomizedSearchCV para XGBoost (en datos muestreados)...
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:42:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:43:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:43:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:43:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:43:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:43:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:43:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/joblib/externals/loky/process_executor.py:782: UserWarning: A worker stopped while some jobs were given to the executor. This can be caused by a too short worker timeout or by a memory leak.
#   warnings.warn(
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:23] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:44:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:45:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:46:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:47:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:47:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:47:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:47:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:47:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:47:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:47:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:01] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:06] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:11] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:48:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:49:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:49:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:49:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:49:50] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:49:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:09] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:50:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:51:47] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:51:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:51:49] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:51:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:51:54] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:51:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:52:24] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:52:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:52:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:52:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:52:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:52:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:53:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:53:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:53:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:53:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:53:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:27] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:54:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:55:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:55:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:55:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:55:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:55:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:55:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:56:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:56:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:56:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:56:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:56:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:56:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:56:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:56:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:57:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:57:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:57:03] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:57:30] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:57:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:57:41] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:57:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:58:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:58:07] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:58:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:58:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:58:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:58:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:59:04] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:59:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:59:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:59:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:59:20] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:59:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:59:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [12:59:45] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:00:10] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:00:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:00:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ...
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:00:51] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:01:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:01:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:01:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:01:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:01:52] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:22] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:26] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:02:48] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:03:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:03:34] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:03:39] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:03:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:03:46] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:05] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:25] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:29] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:31] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:32] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:33] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:04:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:05:08] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:05:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:05:53] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:05:56] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:05:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:05:58] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:06:00] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:06:02] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:06:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:06:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:06:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:06:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:06:42] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:06:44] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:07:36] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:07:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:07:40] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:07:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:07:59] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:08:35] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:08:38] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:09:43] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# --- Búsqueda de Hiperparámetros Completada ---
# Mejores parámetros: {'subsample': 0.8, 'n_estimators': 300, 'max_depth': 9, 'learning_rate': 0.1, 'colsample_bytree': 0.8}
# Mejor F1-Score (ponderado) en validación muestreada: 0.4128

# %%
print("\nEntrenando el modelo XGBoost final en el conjunto de datos completo...")

# Crear e Instanciar el modelo final
model_xgb_final = xgb.XGBClassifier(
    objective='multi:softmax',
    num_class=len(le.classes_),
    eval_metric='mlogloss',
    use_label_encoder=False,
    random_state=42,
    tree_method='hist',
    n_jobs=-1, 
    **best_params_xgb 
)

# Entrenamiento en los datos completos
model_xgb_final.fit(X_train_procesado, y_train_procesado)

print("¡Modelo XGBoost final entrenado exitosamente!")
# Out:
# Entrenando el modelo XGBoost final en el conjunto de datos completo...
# /Users/juanestebanmosquera/Documents/UdeA/2025-2/modelos 1 final/.venv/lib/python3.12/site-packages/xgboost/training.py:199: UserWarning: [13:15:37] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "use_label_encoder" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)
# ¡Modelo XGBoost final entrenado exitosamente!

# %%
print("\nRealizando predicciones finales y generando archivo de envío...")

# 1. Predicción en el conjunto de prueba
predictions_xgb_encoded = model_xgb_final.predict(X_test_transformed)

# 2. Decodificar las predicciones
predictions_xgb_decoded = le.inverse_transform(predictions_xgb_encoded)

# 3. Crear el DataFrame de envío
submission_xgb_df = pd.DataFrame({'ID': test_df['ID'], 'RENDIMIENTO_GLOBAL': predictions_xgb_decoded})

# 4. Guardar el archivo de envío (con un nombre claro)
submission_xgb_df.to_csv('submission_xgb_envio_final.csv', index=False)

print("\n¡Archivo submission_xgb_envio_final.csv creado exitosamente!")
print("Primeras 5 filas:")
print(submission_xgb_df.head())
# Out:
# Realizando predicciones finales y generando archivo de envío...
#
# ¡Archivo submission_xgb_envio_final.csv creado exitosamente!
# Primeras 5 filas:
#        ID RENDIMIENTO_GLOBAL
# 0  550236               bajo
# 1   98545               bajo
# 2  499179               bajo
# 3  782980               bajo
# 4  785185               bajo
